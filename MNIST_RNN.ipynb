# %%
import tensorflow as tf
from tensorflow.contrib import rnn

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('mnist_data', one_hot = True)
# Out:
# WARNING:tensorflow:From C:\Users\perwfart\Anaconda3\envs\TensorFlowCPU\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# WARNING:tensorflow:From <ipython-input-1-8a408f300ef4>:5: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\perwfart\Anaconda3\envs\TensorFlowCPU\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\perwfart\Anaconda3\envs\TensorFlowCPU\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting mnist_data\train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\Users\perwfart\Anaconda3\envs\TensorFlowCPU\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting mnist_data\train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\perwfart\Anaconda3\envs\TensorFlowCPU\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting mnist_data\t10k-images-idx3-ubyte.gz
# Extracting mnist_data\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\perwfart\Anaconda3\envs\TensorFlowCPU\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
#define constants
#unrolled through 28 time steps
time_steps = 28

#hidden LSTM units
num_units = 128

#rows of 28 pixels
n_input = 28

#learning rate for adam
learning_rate = 0.001

#mnist is meant to be classified in 10 classes (0-9)
n_classes = 10
#size of batch
batch_size = 128

#weights and biases of appropriate shape to accomplish the above task
out_weights = tf.Variable(tf.random_normal([num_units, n_classes]))
out_bias = tf.Variable(tf.random_normal([n_classes]))

# %% [markdown]
# ## Placeholders

# %%
#input image placeholder
x =tf.placeholder("float", [None, time_steps, n_input])

#input label placeholder
y = tf.placeholder("float", [None, n_classes])

#processing the input tensor from [batch_size, n_steps, n_input] to "time_steps" number of [batch_size]
input = tf.unstack(x, time_steps, 1)

#defining the network
lstm_layer = rnn.BasicLSTMCell(num_units, forget_bias = 1)
outputs, _ = rnn.static_rnn(lstm_layer, input, dtype = "float32")

# %%
#Converting last ouptut of dimension [batch_size, num_units] to [batch_size, n_classes] by out_we
prediction = tf.matmul(outputs[-1], out_weights) + out_bias

#loss_function
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = prediction, labels = y))

#optimization
opt = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(loss)
# Out:
# WARNING:tensorflow:From <ipython-input-4-60bc0531302d>:5: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %%
#model evaluation
correct_prediction =tf.equal(tf.argmax(prediction, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
#initialize variables
init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    iter = 1
    while iter < 800:
        batch_x, batch_y = mnist.train.next_batch(batch_size = batch_size)
        
        batch_x = batch_x.reshape((batch_size, time_steps, n_input))
        
        sess.run(opt, feed_dict = {x: batch_x, y: batch_y})
        
        if iter % 10 == 0:
            acc = sess.run(accuracy, feed_dict = {x: batch_x, y: batch_y})
            los = sess.run(loss, feed_dict = {x: batch_x, y: batch_y})
            
            print("For iter ", iter)
            print("Accuracy ", acc)
            print("Loss ", los)
            print("___________________")
            
        iter = iter + 1
        
        #calculating test accuracy
    test_data = mnist.test.images[:128].reshape((-1, time_steps, n_input))
    test_label = mnist.test.labels[:128]
    print("Testing Accuracy:", sess.run(accuracy, feed_dict = {x: test_data, y: test_label}))
# Out:
# For iter  10
# Accuracy  0.328125
# Loss  1.8685446
# ___________________
# For iter  20
# Accuracy  0.4296875
# Loss  1.6193471
# ___________________
# For iter  30
# Accuracy  0.5
# Loss  1.3285265
# ___________________
# For iter  40
# Accuracy  0.6953125
# Loss  0.90144324
# ___________________
# For iter  50
# Accuracy  0.75
# Loss  0.7056202
# ___________________
# For iter  60
# Accuracy  0.796875
# Loss  0.73216605
# ___________________
# For iter  70
# Accuracy  0.84375
# Loss  0.55356824
# ___________________
# For iter  80
# Accuracy  0.8203125
# Loss  0.5244354
# ___________________
# For iter  90
# Accuracy  0.84375
# Loss  0.45211166
# ___________________
# For iter  100
# Accuracy  0.828125
# Loss  0.5058794
# ___________________
# For iter  110
# Accuracy  0.84375
# Loss  0.46466786
# ___________________
# For iter  120
# Accuracy  0.875
# Loss  0.4148846
# ___________________
# For iter  130
# Accuracy  0.953125
# Loss  0.19461209
# ___________________
# For iter  140
# Accuracy  0.859375
# Loss  0.35522413
# ___________________
# For iter  150
# Accuracy  0.84375
# Loss  0.355518
# ___________________
# For iter  160
# Accuracy  0.8984375
# Loss  0.3518727
# ___________________
# For iter  170
# Accuracy  0.8671875
# Loss  0.5397743
# ___________________
# For iter  180
# Accuracy  0.875
# Loss  0.39912793
# ___________________
# For iter  190
# Accuracy  0.9140625
# Loss  0.22658259
# ___________________
# For iter  200
# Accuracy  0.9296875
# Loss  0.21050107
# ___________________
# For iter  210
# Accuracy  0.8984375
# Loss  0.34541276
# ___________________
# For iter  220
# Accuracy  0.9140625
# Loss  0.25270635
# ___________________
# For iter  230
# Accuracy  0.953125
# Loss  0.22159243
# ___________________
# For iter  240
# Accuracy  0.921875
# Loss  0.23602316
# ___________________
# For iter  250
# Accuracy  0.953125
# Loss  0.09194982
# ___________________
# For iter  260
# Accuracy  0.9140625
# Loss  0.3350892
# ___________________
# For iter  270
# Accuracy  0.9296875
# Loss  0.23460546
# ___________________
# For iter  280
# Accuracy  0.921875
# Loss  0.18613303
# ___________________
# For iter  290
# Accuracy  0.9296875
# Loss  0.19485918
# ___________________
# For iter  300
# Accuracy  0.8828125
# Loss  0.2658633
# ___________________
# For iter  310
# Accuracy  0.921875
# Loss  0.16343367
# ___________________
# For iter  320
# Accuracy  0.9296875
# Loss  0.2296592
# ___________________
# For iter  330
# Accuracy  0.984375
# Loss  0.08038391
# ___________________
# For iter  340
# Accuracy  0.9375
# Loss  0.13661647
# ___________________
# For iter  350
# Accuracy  0.9765625
# Loss  0.0968851
# ___________________
# For iter  360
# Accuracy  0.9375
# Loss  0.17093316
# ___________________
# For iter  370
# Accuracy  0.96875
# Loss  0.094742805
# ___________________
# For iter  380
# Accuracy  0.90625
# Loss  0.2284438
# ___________________
# For iter  390
# Accuracy  0.921875
# Loss  0.14041044
# ___________________
# For iter  400
# Accuracy  0.953125
# Loss  0.17139831
# ___________________
# For iter  410
# Accuracy  0.9296875
# Loss  0.30801886
# ___________________
# For iter  420
# Accuracy  0.921875
# Loss  0.21628499
# ___________________
# For iter  430
# Accuracy  0.96875
# Loss  0.117333926
# ___________________
# For iter  440
# Accuracy  0.9609375
# Loss  0.07647605
# ___________________
# For iter  450
# Accuracy  0.9609375
# Loss  0.10038406
# ___________________
# For iter  460
# Accuracy  0.9609375
# Loss  0.14973742
# ___________________
# For iter  470
# Accuracy  0.953125
# Loss  0.1423447
# ___________________
# For iter  480
# Accuracy  0.9296875
# Loss  0.23577619
# ___________________
# For iter  490
# Accuracy  0.953125
# Loss  0.1405387
# ___________________
# For iter  500
# Accuracy  0.9453125
# Loss  0.18236859
# ___________________
# For iter  510
# Accuracy  0.984375
# Loss  0.11159168
# ___________________
# For iter  520
# Accuracy  0.96875
# Loss  0.15132433
# ___________________
# For iter  530
# Accuracy  0.9765625
# Loss  0.06353515
# ___________________
# For iter  540
# Accuracy  0.9921875
# Loss  0.02936726
# ___________________
# For iter  550
# Accuracy  0.96875
# Loss  0.09511945
# ___________________
# For iter  560
# Accuracy  0.9375
# Loss  0.1406284
# ___________________
# For iter  570
# Accuracy  0.984375
# Loss  0.056730065
# ___________________
# For iter  580
# Accuracy  0.984375
# Loss  0.06731298
# ___________________
# For iter  590
# Accuracy  0.9921875
# Loss  0.048568666
# ___________________
# For iter  600
# Accuracy  0.9453125
# Loss  0.16680035
# ___________________
# For iter  610
# Accuracy  0.96875
# Loss  0.06053227
# ___________________
# For iter  620
# Accuracy  0.96875
# Loss  0.095255494
# ___________________
# For iter  630
# Accuracy  0.9609375
# Loss  0.12636432
# ___________________
# For iter  640
# Accuracy  0.9765625
# Loss  0.07553607
# ___________________
# For iter  650
# Accuracy  0.953125
# Loss  0.1359803
# ___________________
# For iter  660
# Accuracy  0.96875
# Loss  0.085094735
# ___________________
# For iter  670
# Accuracy  0.9453125
# Loss  0.13429281
# ___________________
# For iter  680
# Accuracy  0.984375
# Loss  0.0850299
# ___________________
# For iter  690
# Accuracy  0.9921875
# Loss  0.05717692
# ___________________
# For iter  700
# Accuracy  0.9765625
# Loss  0.1059607
# ___________________
# For iter  710
# Accuracy  0.96875
# Loss  0.1113481
# ___________________
# For iter  720
# Accuracy  0.96875
# Loss  0.10516245
# ___________________
# For iter  730
# Accuracy  0.9609375
# Loss  0.09805533
# ___________________
# For iter  740
# Accuracy  0.9765625
# Loss  0.08109823
# ___________________
# For iter  750
# Accuracy  0.9609375
# Loss  0.11494528
# ___________________
# For iter  760
# Accuracy  0.9921875
# Loss  0.02828518
# ___________________
# For iter  770
# Accuracy  0.984375
# Loss  0.057627957
# ___________________
# For iter  780
# Accuracy  0.9453125
# Loss  0.111159965
# ___________________
# For iter  790
# Accuracy  0.9921875
# Loss  0.028018381
# ___________________
# Testing Accuracy: 0.9765625
